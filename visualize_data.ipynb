# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('final_processed_ml_dataset.csv')
print('Dimension of dataset= ', df.shape)
df.head() # To get first n rows from the dataset default value of n is 5
# Out:
# Dimension of dataset=  (1104, 6)
#    Type  Floor Size(SQFT)  Number of Rooms  Number of Bathroom  Cluster Label  \
# 0     1               900                2                   2              1
# 1     1               900                2                   2              1
# 2     1              1610                3                   4              1
# 3     1               950                2                   2              1
# 4     1              1250                3                   3              5
#
#    Amount(BDT)
# 0        19000
# 1        19000
# 2        50000
# 3        20000
# 4        20000

# %%
print(df.describe())
# Out:
#          Type  Floor Size(SQFT)  Number of Rooms  Number of Bathroom  \
# count  1104.0       1104.000000      1104.000000         1104.000000
# mean      1.0       1652.146739         2.951087            2.967391
# std       0.0       1267.155717         1.131178            0.988981
# min       1.0        300.000000         1.000000            0.000000
# 25%       1.0       1031.250000         3.000000            2.000000
# 50%       1.0       1400.000000         3.000000            3.000000
# 75%       1.0       2000.000000         3.000000            3.000000
# max       1.0      25900.000000        21.000000           10.000000
#
#        Cluster Label   Amount(BDT)
# count    1104.000000  1.104000e+03
# mean        3.890399  4.792518e+04
# std         2.953821  8.869862e+04
# min         0.000000  8.000000e+03
# 25%         1.000000  1.800000e+04
# 50%         3.000000  2.800000e+04
# 75%         6.000000  5.062500e+04
# max         9.000000  2.100000e+06

# %%
sns.pairplot(data=df, diag_kind='kde')

# %%
sns.boxplot(x = 'Number of Rooms', y = 'Amount(BDT)', data = df)
# Out:
# <AxesSubplot: xlabel='Number of Rooms', ylabel='Amount(BDT)'>

# %%
sns.boxplot(x = 'Cluster Label', y = 'Amount(BDT)', data = df)
# Out:
# <AxesSubplot: xlabel='Cluster Label', ylabel='Amount(BDT)'>

# %%
sns.boxplot(x = 'Floor Size(SQFT)', y = 'Amount(BDT)', data = df)
# Out:
# <AxesSubplot: xlabel='Floor Size(SQFT)', ylabel='Amount(BDT)'>

# %%
sns.boxplot(x = 'Number of Bathroom', y = 'Amount(BDT)', data = df)
# Out:
# <AxesSubplot: xlabel='Number of Bathroom', ylabel='Amount(BDT)'>

# %%
sns.set(style="darkgrid")
sns.histplot(data=df, x="Floor Size(SQFT)", kde=True)
plt.show()

# %%
sns.set(style="darkgrid")
sns.histplot(data=df, x="Number of Rooms", kde=True)
plt.show()

# %%
sns.set(style="darkgrid")
sns.histplot(data=df, x="Number of Bathroom", kde=True)
plt.show()

# %%
sns.set(style="darkgrid")
sns.histplot(data=df, x="Cluster Label", kde=True)
plt.show()
